# %%
import pandas as pd
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
acidentes = pd.read_csv('BaseCompletaNov172.csv', delimiter=';', encoding= 'latin-1')
acidentes.head()
# Out:
#   Cidade Considerada       Regiao Administrativa  Ano Obito  Mes Obito  \
# 0          SAO PAULO  Metropolitana de Sao Paulo       2017         10
# 1          SAO PAULO  Metropolitana de Sao Paulo       2015          6
# 2          SAO PAULO  Metropolitana de Sao Paulo       2015          7
# 3          SAO PAULO  Metropolitana de Sao Paulo       2015          5
# 4          SAO PAULO  Metropolitana de Sao Paulo       2015          1
#
#   Mes Descricao       Sexo           Turno  Tipo Acidente Tipo Veiculo  \
# 0       OUTUBRO  MASCULINO           TARDE  ATROPELAMENTO     PEDESTRE
# 1         JUNHO  MASCULINO           MANHA        COLISAO  MOTOCICLETA
# 2         JULHO  MASCULINO       MADRUGADA         CHOQUE  MOTOCICLETA
# 3          MAIO  MASCULINO           TARDE  ATROPELAMENTO     PEDESTRE
# 4       JANEIRO  MASCULINO  NAO DISPONIVEL  ATROPELAMENTO     PEDESTRE
#
#   Faixa Etaria Idade  Hora Acidente Tipo Vitima Tipo Local do Acidente  \
# ...

# %%
acidentes.dtypes
# Out:
# Cidade Considerada         object
# Regiao Administrativa      object
# Ano Obito                   int64
# Mes Obito                   int64
# Mes Descricao              object
# Sexo                       object
# Turno                      object
# Tipo Acidente              object
# Tipo Veiculo               object
# Faixa Etaria               object
# Idade                      object
# Hora Acidente             float64
# Tipo Vitima                object
# Tipo Local do Acidente     object
# Dia Semana                 object
# Tipo de Via                object
# LAT_(geo)                  object
# LONG_(geo)                 object
# Rua / Rodovia              object
# dtype: object

# %%
acidentes.shape
# Out:
# (16903, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16903 entries, 0 to 16902
# Data columns (total 19 columns):
# Cidade Considerada        16903 non-null object
# Regiao Administrativa     16903 non-null object
# Ano Obito                 16903 non-null int64
# Mes Obito                 16903 non-null int64
# Mes Descricao             16903 non-null object
# Sexo                      16903 non-null object
# Turno                     16903 non-null object
# Tipo Acidente             16903 non-null object
# Tipo Veiculo              16903 non-null object
# Faixa Etaria              16903 non-null object
# Idade                     16903 non-null object
# Hora Acidente             0 non-null float64
# Tipo Vitima               16903 non-null object
# Tipo Local do Acidente    16903 non-null object
# Dia Semana                16903 non-null object
# Tipo de Via               16903 non-null object
# LAT_(geo)                 7460 non-null object
# ...

# %%
acidentes.sample(10)
# Out:
#         Cidade Considerada       Regiao Administrativa  Ano Obito  Mes Obito  \
# 675              SAO PAULO  Metropolitana de Sao Paulo       2015          8
# 15678             BERTIOGA            Baixada Santista       2017          9
# 386              SAO PAULO  Metropolitana de Sao Paulo       2015         10
# 3436   PRESIDENTE PRUDENTE         Presidente Prudente       2015          7
# 10131            SAO PAULO  Metropolitana de Sao Paulo       2016          9
# 10978             CAMPINAS                    Campinas       2016         11
# 12453                TATUI                    Sorocaba       2017          2
# 4608              SOROCABA                    Sorocaba       2015         11
# 9961               JACAREI         Sao Jose dos Campos       2016          9
# 13712              ITUPEVA                    Campinas       2017          5
#
#       Mes Descricao            Sexo  Turno   Tipo Acidente    Tipo Veiculo  \
# ...

# %%
acidentes.columns
# Out:
# Index(['Cidade Considerada', 'Regiao Administrativa', 'Ano Obito', 'Mes Obito',
#        'Mes Descricao', 'Sexo', 'Turno', 'Tipo Acidente', 'Tipo Veiculo',
#        'Faixa Etaria', 'Idade', 'Hora Acidente', 'Tipo Vitima',
#        'Tipo Local do Acidente', 'Dia Semana', 'Tipo de Via', 'LAT_(geo)',
#        'LONG_(geo)', 'Rua / Rodovia'],
#       dtype='object')

# %%
acidentes.describe()
# Out:
#           Ano Obito     Mes Obito  Hora Acidente
# count  16903.000000  16903.000000            0.0
# mean    2015.943442      6.365320            NaN
# std        0.811187      3.317384            NaN
# min     2015.000000      1.000000            NaN
# 25%     2015.000000      4.000000            NaN
# 50%     2016.000000      6.000000            NaN
# 75%     2017.000000      9.000000            NaN
# max     2017.000000     12.000000            NaN

# %%
acidentes.sort_values("Ano Obito")
# Out:
#           Cidade Considerada       Regiao Administrativa  Ano Obito  \
# 4464                   IPERO                    Sorocaba       2015
# 4050                  POLONI       Sao Jose do Rio Preto       2015
# 4049                  POLONI       Sao Jose do Rio Preto       2015
# 4048                  POLONI       Sao Jose do Rio Preto       2015
# 4047                  POLONI       Sao Jose do Rio Preto       2015
# 4046                PLANALTO       Sao Jose do Rio Preto       2015
# 4045                PLANALTO       Sao Jose do Rio Preto       2015
# 4044                PLANALTO       Sao Jose do Rio Preto       2015
# 4043                   NIPOA       Sao Jose do Rio Preto       2015
# 4042                   NIPOA       Sao Jose do Rio Preto       2015
# 4041              PONTALINDA       Sao Jose do Rio Preto       2015
# 4040                   JALES       Sao Jose do Rio Preto       2015
# 4039                   JALES       Sao Jose do Rio Preto       2015
# ...

# %%
acidentes.sort_values("Mes Obito")
# Out:
#           Cidade Considerada       Regiao Administrativa  Ano Obito  \
# 1054             SANTO ANDRE  Metropolitana de Sao Paulo       2015
# 11992             MOGI GUACU                    Campinas       2017
# 11993             MOGI GUACU                    Campinas       2017
# 11994             MOGI MIRIM                    Campinas       2017
# 4914           GUARATINGUETA         Sao Jose dos Campos       2015
# 4915           GUARATINGUETA         Sao Jose dos Campos       2015
# 4916           GUARATINGUETA         Sao Jose dos Campos       2015
# 4927                 JACAREI         Sao Jose dos Campos       2015
# 1675           PARIQUERA ACU                    Registro       2015
# 11991        MOGI DAS CRUZES  Metropolitana de Sao Paulo       2017
# 984    SAO BERNARDO DO CAMPO  Metropolitana de Sao Paulo       2015
# 1676           PARIQUERA ACU                    Registro       2015
# 4947                 TAUBATE         Sao Jose dos Campos       2015
# ...

# %%
df.groupby('Ano Obito').size().sort_values().plot(kind='barh')

# %%
df.groupby('Sexo').size().sort_values().plot(kind='barh')

# %%
df.groupby('Faixa Etaria').size().sort_values().plot(kind='barh')

# %%
df.groupby('Tipo Acidente').size().sort_values().plot(kind='barh')

# %%
df.groupby('Tipo Veiculo').size().sort_values().plot(kind='barh')

# %%
df.groupby('Regiao Administrativa').size().sort_values().plot(kind='barh')

# %%
df.groupby('Mes Descricao').size().sort_values().plot(kind='barh')

# %%
df.groupby('Cidade Considerada').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))
